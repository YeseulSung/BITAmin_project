# %%
from tkinter import *
from tkinter.font import *
from tkinter.messagebox import *
import pickle
import tkinter.ttk as ttk
from main_algorithm import *
import pandas as pd

w = Tk()
w.title('🧚‍반려가구 추천요정🧚‍')

# frame 위젯
topFrame = Frame(w, width=900, height=20)
middleFrame = Frame(w, width=900, height=405)
bottomFrame = Frame(w, width=900, height=400)
# 공통 글꼴
curFont = Font(family='나눔고딕', size=15)

# 이미지 불러오기
photo1 = PhotoImage(file='image/IMG_8983_s.png')

cat = IntVar()
def c1():
    cat.set(1)
    return cat


def c2():
    cat.set(2)
    return cat


def c3():
    cat.set(3)
    return cat


def c4():
    cat.set(4)
    return cat


def c5():
    cat.set(5)
    return cat


def c6():
    cat.set(6)
    return cat


def c0():
    cat.set(0)
    return cat


# 위젯 생성
lblTitle = Label(topFrame, text='✨‍운명의 가구를 찾아드립니다🔮‍', font=('나눔고딕', 20))  # , bg='yellow')
lblImage = Label(middleFrame, image=photo1)
# 입력 위젯
lblsite = Label(bottomFrame, text='▫️당신의 닉네임을 입력하세요 ⤵️', font=('나눔고딕', 20))
site_entry = Entry(bottomFrame, width=30)
lblorder = Label(bottomFrame, text='▫️원하는 느낌의 가구를 선택해 주세요!', font=('나눔고딕', 20))
btn1 = Button(bottomFrame, text='🏡 #맥시멀리스트 #본가의향기 #엄마의향기 #6시내고향템', font=curFont, command=c1)
btn2 = Button(bottomFrame, text='👩‍👩‍👧‍👧 #동거템 #셰어하우스템 #가평펜션템', font=curFont, command=c2)
btn3 = Button(bottomFrame, text='🌿 #홈카페 #인스타갬성템 #빈티지', font=curFont, command=c3)
btn4 = Button(bottomFrame, text='🖥 #기본에충실한 #깔끔 #심플 #모던', font=curFont, command=c4)
btn5 = Button(bottomFrame, text='🧑‍🎓 #가성비템 #학생템 #공부방템', font=curFont, command=c5)
btn6 = Button(bottomFrame, text='🪵 #가격대비만족 #오래쓰자 #한번사서제대로', font=curFont, command=c6)
btn0 = Button(bottomFrame, text='🙅‍찾는 카테고리가 없다면 클릭해 주세요 🤦', font=curFont, command=c0)

result = StringVar()


# 이벤트 구현
def okClick():
    userID = site_entry.get()
    category = cat.get()

    #load model
    checkpoint_path2 = "data/thres_75.ckpt"
    with open('data/vocabularies.pickle', 'rb') as fr:
        vocabularies = pickle.load(fr)
    learning_rate = 0.001
    model2 = model(cross_layer_sizes=2,
                   deep_layer_sizes=[128, 64],
                   learning_rate=learning_rate,
                   vocabularies=vocabularies,
                   threshold=0.75,
                   projection_dim=None,
                   metric='binary'
                   )

    model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                   sample_weight_mode="temporal")
    model2.load_weights(checkpoint_path2)

    #load_data
    item_list = pd.read_csv("data/item_list.csv", encoding="utf-8-sig")
    for_user = pd.read_csv("data/for_user_final_0204.csv", encoding="utf-8-sig")

    #rec
    df = recommendation1(userID=userID, category=category, model=model2, item_list=item_list, for_user=for_user)

    #treeview
    frame = Frame(w)
    frame.pack()

    tree = ttk.Treeview(frame, columns=tuple(range(4)), height=5, show="headings")
    tree.pack(side='left')
    tree.heading(0, text=df.columns[0], anchor="center")
    tree.heading(1, text=df.columns[1], anchor="center")
    tree.heading(2, text=df.columns[2], anchor="center")
    tree.heading(3, text=df.columns[3], anchor="center")

    tree.column(0, width=100)
    tree.column(1, width=100)
    tree.column(2, width=100)
    tree.column(3, width=100)
    scroll = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
    scroll.pack(side='right', fill='y')
    tree.configure(yscrollcommand=scroll.set)
    for val in np.array(df).tolist():
        tree.insert('', 'end', values=(val[0], val[1], val[2]))
    label = Label(w, text="뾰로롱✨")
    label.pack() # 테이블 항목 클릭시 click_item 호출

    #result.set(res)

    #print(result)
    #showinfo("추천 결과입니다", result.get())


# 저장 위젯  (이벤트 추가 >>   command=okClick )
savebtn = Button(bottomFrame, text='   입력    ', font=curFont, command=okClick)

# 위젯 배치
# site_entry.grid(row=0, column=3)
# lblsite.grid(row=0, column=0)
# lblorder.grid(row = 15, column = 3)
# btn1.grid(row = 30, column = 0)
# btn2.grid(row = 30, column = 3)
# btn3.grid(row = 40, column = 0)
# btn4.grid(row = 40, column = 5)
# btn5.grid(row = 50, column = 0)
# btn6.grid(row = 50, column = 5)
# btn0.grid(row = 60, column = 0)
# savebtn.grid(row=70, column=5)

lblsite.pack()
site_entry.pack()
lblorder.pack()
btn1.pack()
btn2.pack()
btn3.pack()
btn4.pack()
btn5.pack()
btn6.pack()
btn0.pack()
savebtn.pack()
lblImage.pack()
lblTitle.pack()

topFrame.pack()
middleFrame.pack()
bottomFrame.pack()
w.geometry('1000x1000')
w.mainloop()
# Out:
# 2022-02-05 20:55:48.058 python[66556:6186325] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Metal device set to: Apple M1
# WARNING:tensorflow:mask_value is deprecated, use mask_token instead.
# 2022-02-05 20:55:52.241169: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-02-05 20:55:52.241952: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._logit_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._logit_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).task._loss_metrics
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.0._dense
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.1._dense
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._deep_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._deep_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._deep_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._deep_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.user.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_name.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_brand.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_category1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_category2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_category3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.review.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_sale_price.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.item_count.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.n1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.n2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.n3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.n4.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.c6.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.total_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.dur_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.price_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.design_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.delivery_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._embeddings.options.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.0._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.0._dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.1._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._cross_layer.1._dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._logit_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._logit_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._deep_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._deep_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._deep_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._deep_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.user.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_name.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_brand.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_category1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_category2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_category3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.review.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_sale_price.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.item_count.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.n1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.n2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.n3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.n4.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.c6.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.total_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.dur_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.price_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.design_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.delivery_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._embeddings.options.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._cross_layer.0._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._cross_layer.0._dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._cross_layer.1._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root)._cross_layer.1._dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._logit_layer.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._logit_layer.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._deep_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._deep_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._deep_layers.1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._deep_layers.1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.user.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_name.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_brand.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_category1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_category2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_category3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.review.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_sale_price.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.item_count.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.n1.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.n2.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.n3.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.n4.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.c6.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.total_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.dur_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.price_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.design_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.delivery_score.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._embeddings.options.layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._cross_layer.0._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._cross_layer.0._dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._cross_layer.1._dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root)._cross_layer.1._dense.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
